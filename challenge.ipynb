# %%
import psycopg2
conn = psycopg2.connect('host=db dbname=postgres user=postgres password=postgres')

# %%
# !pip install markdown
# !pip install rasa_nlu
import markdown
import rasa_nlu
import pandas as pd
import json
# Out:
# ...
#      |████████████████████████████████| 147 kB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 829 kB 4.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 36.7 MB 92 kB/s  eta 0:00:01    |██▎                             | 2.6 MB 8.5 MB/s eta 0:00:05     |███████▋                        | 8.8 MB 514 kB/s eta 0:00:55     |█████████████████               | 19.4 MB 3.4 MB/s eta 0:00:06     |██████████████████████████▊     | 30.7 MB 3.2 MB/s eta 0:00:02     |█████████████████████████████   | 33.2 MB 2.1 MB/s eta 0:00:02
#     ERROR: Command errored out with exit status 1:
# ...

# %%
import pandas as pd
df = pd.read_json('../dataset/schema.md')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, type to TLE_LINE2
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   version       1 non-null      object
#  1   launch        2 non-null      object
#  2   longitude     1 non-null      object
#  3   latitude      1 non-null      object
#  4   height_km     1 non-null      object
#  5   velocity_kms  1 non-null      object
#  6   spaceTrack    41 non-null     object
# dtypes: object(7)
# memory usage: 2.8+ KB

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@db:5432/postgres')

# %%
#with open('../dataset/schema.md', 'r') as f:
#    data = json.loads(f.read())
#df_space_track = pd.json_normalize(data, record_path=['spaceTrack'])

# %%
with open('../dataset/schema.md', 'r') as f:
    text = f.read()
    result = markdown.markdown(text)

# %%
print(result)
# Out:
# <p>{
#     "version": {
#         "type": "String",
#         "default": null
#     },
#     "launch": {
#         "type": "UUID",
#         "ref": "Launch",
#         "default": null
#     },
#     "longitude": {
#         "type": "Number",
#         "default": null,
#     },
#     "latitude": {
#         "type": "Number",
#         "default": null,
#     },
#     "height_km": {
#         "type": "Number",
#         "default": null,
#     },
#     "velocity_kms": {
#         "type": "Number",
#         "default": null,
#     },
#     "spaceTrack": {
#         "CCSDS_OMM_VERS": {
#             "type": "String",
#             "default": null
#         },
#         "COMMENT": {
#             "type": "String",
#             "default": null
#         },
#         "CREATION_DATE": {
#             "type": "String",
#             "default": null
#         },
#         "ORIGINATOR": {
#             "type": "String",
#             "default": null
#         },
#         "OBJECT_NAME": {
# ...

# %%
import rasa_nlu
from rasa_nlu.training_data import load_data

input_training_file_md_file = "../dataset/schema.md"


output_json_file = '../dataset/schema.json'

with open(output_json_file,'w') as f:
    f.write(load_data(input_training_file_md_file).as_json())
#done

# %%
import pandas as pd
df = pd.read_json('../dataset/schema.md')

# %%
df.head()
# Out:
#                version  launch longitude latitude height_km velocity_kms  \
# type            String    UUID    Number   Number    Number       Number
# default           None    None      None     None      None         None
# ref                NaN  Launch       NaN      NaN       NaN          NaN
# CCSDS_OMM_VERS     NaN     NaN       NaN      NaN       NaN          NaN
# COMMENT            NaN     NaN       NaN      NaN       NaN          NaN
#
#                                          spaceTrack
# type                                            NaN
# default                                         NaN
# ref                                             NaN
# CCSDS_OMM_VERS  {'type': 'String', 'default': None}
# COMMENT         {'type': 'String', 'default': None}

# %%
with open('../dataset/schema.json') as f:
    data = json.loads(f.read())
df_s = pd.json_normalize(data, record_path=['spaceTrack'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-f6b4e35ac8d5> in <module>
#       1 with open('../dataset/schema.json') as f:
#       2     data = json.loads(f.read())
# ----> 3 df_s = pd.json_normalize(data, record_path=['spaceTrack'])
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     307         else:
#     308             for obj in data:
# --> 309                 recs = _pull_records(obj, path[0])
#     310                 recs = [
# ...
