# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/500000-Sales-Records.csv')

# %%
df.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
import psycopg2
conn = psycopg2.connect('host=db dbname=postgres user=postgres password=postgres')

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@db:5432/postgres')

# %%
df.to_sql('test', engine)

df_pg = pd.read_sql_query('Select * from test', con=engine)

df_pg.head()
# Out:
#    index                        Region           Country  Item Type  \
# 0      0            Sub-Saharan Africa      South Africa     Fruits
# 1      1  Middle East and North Africa           Morocco    Clothes
# 2      2         Australia and Oceania  Papua New Guinea       Meat
# 3      3            Sub-Saharan Africa          Djibouti    Clothes
# 4      4                        Europe          Slovakia  Beverages
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              M   7/27/2012  443368995   7/28/2012        1593
# 1        Online              M   9/14/2013  667593514  10/19/2013        4611
# 2       Offline              M   5/15/2015  940995585    6/4/2015         360
# 3       Offline              H   5/17/2017  880811536    7/2/2017         562
# 4       Offline              L  10/26/2016  174590194   12/4/2016        3973
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...
